# %% [markdown]
# # Tear Sheet

# %%
bt = get_backtest('590698c73d588d61c237a566')
# Out:
# 100% Time: 0:00:08|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2014-12-01
# Entire data end date: 2016-02-01
#
#
# Backtest Months: 14
# Performance statistics   Backtest
# annual_return                0.05
# cum_returns_final            0.05
# annual_volatility            0.05
# sharpe_ratio                 0.84
# calmar_ratio                 0.75
# stability_of_timeseries      0.23
# max_drawdown                -0.06
# omega_ratio                  1.15
# sortino_ratio                1.21
# skew                        -0.41
# kurtosis                     2.80
# tail_ratio                   1.06
# common_sense_ratio           1.10
# gross_leverage               2.00
# information_ratio            0.03
# alpha                        0.05
# beta                        -0.02
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                   6.03 2015-01-15  2015-05-26    2015-08-04
# 1                                   3.88 2015-08-05  2015-09-16    2015-12-17
# ...
