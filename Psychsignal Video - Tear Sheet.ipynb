# %% [markdown]
# # Tear Sheet

# %%
bt = get_backtest('590086c65b3aab656f85a240')
# Out:
# 100% Time: 0:00:46|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2013-12-02
# Entire data end date: 2014-12-01
#
#
# Backtest Months: 12
# Performance statistics   Backtest
# annual_return                0.15
# cum_returns_final            0.15
# annual_volatility            0.07
# sharpe_ratio                 2.05
# calmar_ratio                 4.58
# stability_of_timeseries      0.89
# max_drawdown                -0.03
# omega_ratio                  1.39
# sortino_ratio                3.27
# skew                         0.01
# kurtosis                     0.33
# tail_ratio                   1.25
# common_sense_ratio           1.44
# gross_leverage               2.00
# information_ratio           -0.01
# alpha                        0.15
# beta                        -0.10
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                   3.18 2014-10-15  2014-11-21           NaT
# 1                                   1.94 2014-05-08  2014-05-19    2014-07-10
# ...
